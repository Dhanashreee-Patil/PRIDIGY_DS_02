# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanashreee-Patil/PRODIGY_DS_02/blob/main/PRODIGY_DS_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['embark_town'].value_counts()
# Out:
# Southampton          644
# Cherbourg            168
# Queenstown            77
# 29.69911764705882      2
# Name: embark_town, dtype: int64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# Southampton          644
# Cherbourg            168
# Queenstown            77
# 29.69911764705882      2
# Name: embark_town, dtype: int64

# %%
df=df.drop(['deck'],axis=1)

# %%
df=df.rename(columns={'sex':'gender'})
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df=df.fillna(df['embark_town'].mode())

# %%
df=df.fillna(df['age'].mean())
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df=df.drop('embarked',axis=1)
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
df=df.drop('who',axis=1)
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare  class  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500  Third        True
# 1         1       1  female  38.0      1      0  71.2833  First       False
# 2         1       3  female  26.0      0      0   7.9250  Third       False
# 3         1       1  female  35.0      1      0  53.1000  First       False
# 4         0       3    male  35.0      0      0   8.0500  Third        True
#
#    embark_town alive  alone
# 0  Southampton    no  False
# 1    Cherbourg   yes  False
# 2  Southampton   yes   True
# 3  Southampton   yes  False
# 4  Southampton    no   True

# %%
df['parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: parch, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# Southampton          644
# Cherbourg            168
# Queenstown            77
# 29.69911764705882      2
# Name: embark_town, dtype: int64

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# gender         0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='plasma')
# Out:
# <ipython-input-57-2ce89a1ffe31>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %%
sns.pairplot(df,hue="gender")

# %%
sns.barplot(x='survived',y='age',data=df,hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %% [markdown]
# In pclass 1 there are maximum number of survived people and
# pclass 3 has minimum number of survived people

# %%
sns.countplot(x=df.embark_town)
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %% [markdown]
# southampton town has the higher number of peoples

# %%
sns.lineplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %% [markdown]
# people of age 30 to 31 are higher in number

# %%
sns.violinplot(data=df,x='gender',y='pclass')
# Out:
# <Axes: xlabel='gender', ylabel='pclass'>

# %% [markdown]
# there are maximum numbers of males in pclass 3 and less in pclass 1 comapared to females

# %% [markdown]
# Conclusion : After analysing given dataset we can conclude that maximum survived peoples are from southampton town and from pclass 1 and have age in the range of 20 to 30 .Number of male people are higher than number of females.

# %%
from sklearn.preprocessing import LabelEncoder
gender_encoder=LabelEncoder()
df['gEncoder']=gender_encoder.fit_transform(df['gender'])
df
# Out:
#      survived  pclass  gender        age  sibsp  parch     fare   class  \
# 0           0       3    male  22.000000      1      0   7.2500   Third
# 1           1       1  female  38.000000      1      0  71.2833   First
# 2           1       3  female  26.000000      0      0   7.9250   Third
# 3           1       1  female  35.000000      1      0  53.1000   First
# 4           0       3    male  35.000000      0      0   8.0500   Third
# ..        ...     ...     ...        ...    ...    ...      ...     ...
# 886         0       2    male  27.000000      0      0  13.0000  Second
# 887         1       1  female  19.000000      0      0  30.0000   First
# 888         0       3  female  29.699118      1      2  23.4500   Third
# 889         1       1    male  26.000000      0      0  30.0000   First
# 890         0       3    male  32.000000      0      0   7.7500   Third
#
#      adult_male  embark_town alive  alone  gEncoder
# ...
